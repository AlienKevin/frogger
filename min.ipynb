# %%
import gymnasium as gym
import ale_py
import matplotlib.pyplot as plt

# %%
env = gym.make("ALE/Frogger-v5", render_mode="rgb_array", mode=2)

state, info = env.reset()

plt.imshow(state)

# %%
for i in range(110):
    action = 1 # UP
    state, reward, terminated, truncated, _ = env.step(action)

# %%
plt.imshow(state)
